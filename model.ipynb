# %% [markdown]
# TRAINING THE MODEL

# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader

# %%
transform = transforms.Compose(
    [transforms.Resize((64,64)), transforms.ToTensor()]
    )

# %%
train_data = datasets.ImageFolder(
    "dataset/train",
    transform=transform
)

# %%
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
print(train_data.classes)
# Out:
# ['NoTrees', 'Trees']

# %%
model = models.resnet18(pretrained=True)

# %%
model.fc = nn.Linear(model.fc.in_features, 2)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
epochs = 14

for epoch in range(epochs):
    model.train()
    total_loss = 0 

    for images, labels in train_loader:
        outputs = model(images)
        loss = criterion(outputs,labels)

        optimizer.zero_grad()

        #backpropagation
        loss.backward()

        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")
# Out:
# Epoch 1, Loss: 42.8402
# Epoch 2, Loss: 29.6630
# Epoch 3, Loss: 27.2446
# Epoch 4, Loss: 25.0452
# Epoch 5, Loss: 24.9761
# Epoch 6, Loss: 25.6638
# Epoch 7, Loss: 20.7061
# Epoch 8, Loss: 19.6698
# Epoch 9, Loss: 31.1062
# Epoch 10, Loss: 23.2455
# Epoch 11, Loss: 22.2209
# Epoch 12, Loss: 19.3302
# Epoch 13, Loss: 19.4245
# Epoch 14, Loss: 19.1495

# %%
torch.save(model.state_dict(), "forest_model_epoch_14.pth")
print("Model Saved!")
# Out:
# Model Saved!
